# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Utilities" data-toc-modified-id="Utilities-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Utilities</a></span><ul class="toc-item"><li><span><a href="#Plotting" data-toc-modified-id="Plotting-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Plotting</a></span></li><li><span><a href="#Geometry" data-toc-modified-id="Geometry-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Geometry</a></span></li><li><span><a href="#Time-Handling" data-toc-modified-id="Time-Handling-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Time Handling</a></span></li></ul></li><li><span><a href="#Generation-of-Input-Data" data-toc-modified-id="Generation-of-Input-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Generation of Input Data</a></span><ul class="toc-item"><li><span><a href="#Generate-Parcels" data-toc-modified-id="Generate-Parcels-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Generate Parcels</a></span></li><li><span><a href="#Testing-Parcel-Data-Generation" data-toc-modified-id="Testing-Parcel-Data-Generation-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Testing Parcel Data Generation</a></span></li><li><span><a href="#Statistical-Analysis-of-Parcel-Data" data-toc-modified-id="Statistical-Analysis-of-Parcel-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Statistical Analysis of Parcel Data</a></span></li></ul></li><li><span><a href="#Shortest-Path-Finding" data-toc-modified-id="Shortest-Path-Finding-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Shortest Path Finding</a></span><ul class="toc-item"><li><span><a href="#A*-Algorithm" data-toc-modified-id="A*-Algorithm-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>A* Algorithm</a></span></li><li><span><a href="#Floyd-Warshall-Algorithm" data-toc-modified-id="Floyd-Warshall-Algorithm-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Floyd-Warshall Algorithm</a></span></li><li><span><a href="#Testing-Shortest-Path" data-toc-modified-id="Testing-Shortest-Path-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Testing Shortest Path</a></span></li></ul></li><li><span><a href="#Create-Roundtrip" data-toc-modified-id="Create-Roundtrip-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Create Roundtrip</a></span><ul class="toc-item"><li><span><a href="#Using-Iterative-Integer-Programming" data-toc-modified-id="Using-Iterative-Integer-Programming-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Using Iterative Integer Programming</a></span></li><li><span><a href="#Using-Heuristic-Method" data-toc-modified-id="Using-Heuristic-Method-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Using Heuristic Method</a></span></li><li><span><a href="#Testing-Generating-Roundtrip" data-toc-modified-id="Testing-Generating-Roundtrip-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Testing Generating Roundtrip</a></span></li></ul></li><li><span><a href="#Recorder" data-toc-modified-id="Recorder-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Recorder</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model</a></span><ul class="toc-item"><li><span><a href="#Class-Parcel" data-toc-modified-id="Class-Parcel-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Class Parcel</a></span></li><li><span><a href="#Class-Customer" data-toc-modified-id="Class-Customer-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Class Customer</a></span></li><li><span><a href="#Class-Driver" data-toc-modified-id="Class-Driver-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Class Driver</a></span></li><li><span><a href="#Class-Delivery-Centre" data-toc-modified-id="Class-Delivery-Centre-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Class Delivery Centre</a></span></li></ul></li><li><span><a href="#Simulation" data-toc-modified-id="Simulation-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Simulation</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Simulation-Routine" data-toc-modified-id="Simulation-Routine-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Simulation Routine</a></span></li><li><span><a href="#Model-Verification" data-toc-modified-id="Model-Verification-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Model Verification</a></span></li><li><span><a href="#Run-Small-Simulation" data-toc-modified-id="Run-Small-Simulation-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Run Small Simulation</a></span><ul class="toc-item"><li><span><a href="#Analysing-Working-Time" data-toc-modified-id="Analysing-Working-Time-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Analysing Working Time</a></span></li><li><span><a href="#Analyse-Tour-Length" data-toc-modified-id="Analyse-Tour-Length-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Analyse Tour Length</a></span></li><li><span><a href="#Analyse-Number-of-Left-Over-Parcels" data-toc-modified-id="Analyse-Number-of-Left-Over-Parcels-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>Analyse Number of Left-Over Parcels</a></span></li><li><span><a href="#Analyse-Delayed-Parcel-Delivery" data-toc-modified-id="Analyse-Delayed-Parcel-Delivery-7.4.4"><span class="toc-item-num">7.4.4&nbsp;&nbsp;</span>Analyse Delayed Parcel Delivery</a></span></li></ul></li><li><span><a href="#Run-Multiple-Larger-Simulation" data-toc-modified-id="Run-Multiple-Larger-Simulation-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Run Multiple Larger Simulation</a></span><ul class="toc-item"><li><span><a href="#Run-Simulations" data-toc-modified-id="Run-Simulations-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Run Simulations</a></span></li><li><span><a href="#Combine-Simulation" data-toc-modified-id="Combine-Simulation-7.5.2"><span class="toc-item-num">7.5.2&nbsp;&nbsp;</span>Combine Simulation</a></span></li><li><span><a href="#Analysis" data-toc-modified-id="Analysis-7.5.3"><span class="toc-item-num">7.5.3&nbsp;&nbsp;</span>Analysis</a></span></li><li><span><a href="#Tour-Length" data-toc-modified-id="Tour-Length-7.5.4"><span class="toc-item-num">7.5.4&nbsp;&nbsp;</span>Tour Length</a></span></li><li><span><a href="#Number-of-Left-Over-Parcels" data-toc-modified-id="Number-of-Left-Over-Parcels-7.5.5"><span class="toc-item-num">7.5.5&nbsp;&nbsp;</span>Number of Left-Over Parcels</a></span></li><li><span><a href="#Delayed-Parcel-Delivery" data-toc-modified-id="Delayed-Parcel-Delivery-7.5.6"><span class="toc-item-num">7.5.6&nbsp;&nbsp;</span>Delayed Parcel Delivery</a></span></li></ul></li></ul></li></ul></div>

# %%
import math
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Plotting

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=5,
            styleP='b-o', lwP=3, msP=1,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, size=6):
    fig = plt.gcf()
    fig.set_size_inches(size, size)
    resolution = 10000
    plt.xlim(0,resolution)
    plt.ylim(0,resolution)
    if not grid:
        plt.axis('off')
    V, E = G
    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if grid:
        plt.grid()
        if text is not None:
            plt.title(text)
    else:
        if text is not None:
            plt.text(0.8*resolution, 0, text)

    plt.show()

# %%
import scipy.stats as stats

def histplot(data, title="", xlabel="",
             width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()
        
    bins=min(50, min(len(data),maxx-minx)//5+1)
    hist=plt.hist(data, density=True, bins=bins)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)
        
    x = np.linspace(minx, maxx, 100)
    y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
    ax.plot(x, y, lw=1, color='red')
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    ax.grid(True)
    plt.show()
# Out:
# c:\Users\chitt\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def dailyPlot(data,
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data))*0.1
    ymin = int(math.floor(min(data)-diff))
    ymax = int(math.ceil(max(data)+diff))
    ax.set_xlim(-1, days)
    ax.set_ylim(ymin, ymax)
    ax.grid(True)
    
    ms = 2 if len(data)>100 else 5
    lw = 0.5 if len(data)>100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
def barPlot(count, title=''):
    fig = plt.figure()
    fig.set_figwidth(3 if len(count)<=10 else 5)
    fig.set_figheight(2)
    ax = fig.gca()
    xpos = np.arange(0, len(count))
    labels = [ c for c in range(0, len(count)) ]
    ax.set_xticks(xpos, labels)
    plt.title(title)
    plt.bar(range(0, len(count)), count)

# %% [markdown]
# ## Geometry

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.ceil(math.sqrt((x1-x2)**2+(y1-y2)**2)))

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %% [markdown]
# ## Time Handling

# %% [markdown]
# For this project, we'll utilize seconds as our time measurement unit, and the simulation will commence at 0:00. As we proceed, we'll incorporate various functions to manage time-related operations and computations.

# %%
def day(now):
    return int(now//(24*3600))

# %%
def timestamp(t):
    """
    Generates a timestamp string in the format '[dd] hh:mm:ss.d' for trace messages, using time in seconds (as a float) as input.
    The returned string includes days, hours, minutes, seconds, and tenths of a second."""
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t - secs)*10))
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(86400 * 7 + 7200 + 240.5)
# Out:
# '[ 7] 02:04:00.5'

# %% [markdown]
# The `nextHour` function calculates the simulation time for the next occurrence of the specified hour in the simulation

# %%
def nextHour(env, hour):
    beginningOfDay = day(env.now)*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# # Generation of Input Data

# %% [markdown]
# ## Generate Parcels

# %% [markdown]
# `generateParcels` returns for each day a list of customers that should receive parcels on that day. The data are generated for a given number of customers and days under assumption that the demand is independent and identically distributed with a mean value

# %%
def generateParcels(days=50, customers=100, 
                    p=0.25, plot=False, log=False):

    # daily delivery demand is generated for each customer 
    # independently using an expovariate distribution
    
    parcelsForCustomersPerDay = [ [] for i in range(days) ]
    parcelsPerCustomer = [ 0 for i in range(customers) ]
    parcelsPerDay = [ 0 for i in range(days) ]

    for c in range(customers):
        cp = []
        t = random.expovariate(p/(24*3600)) # arrival time secs
        d = day(t)
        deliveryDays = []
        while d<days:
            if d not in deliveryDays:
                deliveryDays.append(d)
            parcelsForCustomersPerDay[d].append(c)
            parcelsPerDay[d] += 1
            parcelsPerCustomer[c] += 1
            if d not in cp:
                cp.append(d)
            t += random.expovariate(p/(24*3600))
            d = day(t)
        
        if log:
            print(f"customer {c:3d} "
                  f"expects {parcelsPerCustomer[c]:2d} deliveries "
                  f"on days {str(cp):s}")
    
    if plot:
        
        histplot(parcelsPerCustomer,
                 xlabel=f'Number of Parcels (over {days:3,d} days, p={p:2.2f})',
                 title=f'Number of Parcels per Customer (N={customers:3,d})')
        
        histplot(parcelsPerDay,
                 xlabel=f'Number of Parcels (over {customers:3,d} customers, p={p:2.2f})',
                 title=f'Number of Parcels per Day (N={days:3,d})')
        
    return parcelsForCustomersPerDay

# %% [markdown]
# ## Testing Parcel Data Generation

# %%
random.seed(0)
generateParcels(days=4, customers=5, p=0.5, log=True)
# Out:
# customer   0 expects  1 deliveries on days [3]
# customer   1 expects  3 deliveries on days [1, 3]
# customer   2 expects  2 deliveries on days [3]
# customer   3 expects  1 deliveries on days [1]
# customer   4 expects  2 deliveries on days [1, 2]
# [[], [1, 1, 3, 4], [4], [0, 1, 2, 2]]

# %% [markdown]
# ## Statistical Analysis of Parcel Data

# %%
random.seed(0)
_ = generateParcels(days=1000, customers=1000, p=0.4, plot=True)

# %% [markdown]
# # Shortest Path Finding

# %% [markdown]
# ## A* Algorithm

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# ## Floyd-Warshall Algorithm

# %% [markdown]
# The following is a modified
# [Floyd-Warshall Algorithm](https://en.wikipedia.org/wiki/Floyd–Warshall_algorithm)
# calculating in parallel the distances and the shortest path between vertices in a graph M.

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %% [markdown]
# ## Testing Shortest Path

# %%
import pickle
with open('myData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
V, E = M
d, p = FW(M)
random.seed(0)
[A, B] = random.sample(V, k=2)
a = V.index(A)
b = V.index(B)
P1 = p[a][b]
L1 = d[a][b]
plotMap(M, T=[A, B], P=P1, text=f"FW path: {L1:d}m")
P2 = shortestPath(M, A, B)
L2 = pathLength(P2)
plotMap(M, T=[A, B], P=P2, text=f"A* path: {L2:d}m")
P1==P2
# Out:
# True

# %% [markdown]
# # Create Roundtrip

# %% [markdown]
# ## Using Iterative Integer Programming

# %%
import pulp

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
def createLoop(M, D, P, T):
    V, E = M
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[V.index(T[i])][V.index(T[j])]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0)
    # print(f"{constraints:d} Constraints")
    prob.solve(solver)
    trips = roundtrips(x, n)
    while len(trips)>1:
        for t in trips:
            prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                            for i in range(0,len(t)-1) ]) <= len(t)-2
            constraints += 1
        # print(f"{constraints:d} Constraints")
        prob.solve(solver)
        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[V.index(T[trip[k]])][V.index(T[trip[k+1]])]
        loop += sub if len(loop)==0 else sub[1:]
    return loop

# %% [markdown]
# ## Using Heuristic Method

# %%
def createLoopH(M, D, P, T, plot=False):
    
    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
    
    V, E = M
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            if plot:
                loop = makeLoop(L)
                plotMap(M, T=L, P=loop, w=W, 
                        grid=True, text=f"{pathLength(loop):,d}m")
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
    return makeLoop(L)

# %% [markdown]
# ## Testing Generating Roundtrip

# %%
import pickle
with open('myData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
D, P = FW(M)

# %%
random.seed(0)
customers = random.sample(C, k=25)

# %%
L = createLoop(M, D, P, [W]+customers)

# %%
plotMap(M, T=customers, P=L, w=W, 
        text=f"IP Solution: {pathLength(L):,d}m")

# %%
L2 = createLoopH(M, D, P, [W]+customers)

# %%
plotMap(M, T=customers, P=L, w=W, 
        text=f"Heuristic SolutionL {pathLength(L):,d}m")

# %% [markdown]
# # Recorder

# %%
class Recorder:
    
    def __init__(self, env, M, W, C, days, parcels,
                 log=False, plot=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.parcels = parcels
        self.log = log
        self.plot = plot
        Customer.REGISTER = []
        Parcel.REGISTER = []
                
        # create a data frame for time records per working day
        self.daily = pd.DataFrame()
        self.daily['begin'] = [None]*days
        self.daily['end'] = [None]*days
        self.daily['dist'] = [None]*days
        self.daily['left'] = [None]*days
        
        # create a data frame for records per parcel
        self.precs = pd.DataFrame()
        self.precs['arrived'] = [None]*parcels
        self.precs['delivered'] = [None]*parcels

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def recordDriverBeginsWork(self):
        self.trace("Driver arrives for work")
        self.daily.at[day(self.env.now), 'begin'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self):
        self.trace("Driver goes home")
        self.daily.at[day(self.env.now), 'end'] = int(round(self.env.now))

    def recordTourLength(self, length):
        self.daily.at[day(self.env.now), 'dist'] = int(length)

    def recordParcelsLeftOver(self, numberOfParcels):
        self.trace(f"{numberOfParcels:d} left over for next day")
        self.daily.at[day(self.env.now), 'left'] = numberOfParcels

    def recordParcelArrival(self, parcel):
        self.trace(f"{str(parcel):s} arrived in delivery centre")
        self.precs.at[parcel.i, 'arrived'] = day(self.env.now)
        
    def recordParcelDelivery(self, parcel):
        self.trace(f"{str(parcel):s} delivered to customer")
        self.precs.at[parcel.i, 'delivered'] = day(self.env.now)

    def finish(self):
        self.daily['time'] = self.daily['end']-self.daily['begin']
        # if at the end of the simulation there are parcels 
        # not yet delivered, register them for the next day
        for i in range(self.parcels):
            if self.precs.at[i, 'delivered'] is None:
                self.precs.at[i, 'delivered'] = self.days
        self.precs['delay'] = self.precs['delivered']-self.precs['arrived']
        # calculate max delay time of parcels delivered on a day
        self.daily['maxdelay'] = [0] * self.days
        for i in range(self.parcels):
            deliveryDay = self.precs.at[i, 'delivered']
            if deliveryDay < self.days:
                if self.daily.at[deliveryDay, 'maxdelay'] < self.precs.at[i, 'delay']:
                    self.daily.at[deliveryDay, 'maxdelay'] = self.precs.at[i, 'delay']
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None
        
    def histWorkingTime(self):
        histplot(self.daily['time']//60,
                 xlabel='Working Time [min]',
                 title='Daily Working Time')
        
    def plotWorkingTime(self):
        dailyPlot(self.daily['time']//60,
                  ylabel='Working Time [min]',
                  title='Daily Working Time')
            
    def histTourLength(self):
        histplot(self.daily['dist'],
                 xlabel='Tour Length [m]',
                 title='Daily Tour Length')
            
    def plotTourLength(self):
        dailyPlot(self.daily['dist'],
                  ylabel='Tour Length [m]',
                  title='Daily Tour Length')
            
    def histLeftOver(self):
        histplot(self.daily['left'],
                 xlabel='Left-Over Parcels',
                 title='Daily Left-Over Parcels')
                
    def plotLeftOver(self):
        dailyPlot(self.daily['left'],
                  ylabel='Number of Parcels',
                  title='Daily Left-Over Parcels')
        
    def plotParcelDelay(self):
        dailyPlot(self.daily['maxdelay'],
                  ylabel='Max Delay [days]',
                  title='Max Delivery Delay')
        
    def barplotParcelDelay(self):
        maxDelay = max(self.precs['delay'])
        count = [ 0 for c in range(maxDelay+1) ]
        for i in range(self.parcels):
            count[self.precs.at[i, 'delay']] += 1
        barPlot(count, title='Parcel Delay [days]')
        
    def tableParcelDelay(self):
        maxDelay = max(self.precs['delay'])
        count = [ 0 for c in range(maxDelay+1) ]
        for i in range(self.parcels):
            count[self.precs.at[i, 'delay']] += 1
        print(f'Delivery Delay ({self.parcels:d} parcels)')
        print(f'{"None":>7s}:   {count[0]:4d}   {count[0]/self.parcels*100:4.1f}%')
        for c in range(1, len(count)):
            print(f'{c:2d} days:   {count[c]:4d}   {count[c]/self.parcels*100:4.1f}%')

# %%
def combineRecorders(recs): 
    M = recs[0].M
    W = recs[0].W
    C = recs[0].C
    days = sum( [ rec.days for rec in recs ] )
    parcels = sum( [ rec.parcels for rec in recs ])
    # ensure the models are compatible
    for rec in recs[1:]:
        assert(M == rec.M)
        assert(W == rec.W)
        assert(C == rec.C)
        
    r = Recorder(None, M, W, C, days, parcels)
    
    # join the data frames
    r.daily = pd.concat([ rec.daily for rec in recs ], ignore_index=True)
    r.precs = pd.concat([ rec.precs for rec in recs ], ignore_index=True)
    return r

# %% [markdown]
# # Model

# %% [markdown]
# ## Class Parcel

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    REGISTER = []
    
    def __init__(self, rec, cust):
        self.rec = rec
        self.cust = cust
        self.dest = cust.location
        self.status = [ ] # status record and
        self.timing = [ ] # timing
        self.i = len(Parcel.REGISTER)
        Parcel.REGISTER.append(self)

    def __str__(self):
        return f"Parcel: {self.i:2d} for customer {self.cust.i:d}"
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')
        
    def delivered(self):
        self.rec.recordParcelDelivery(parcel)
        self.__reg('delivered to customer')

# %% [markdown]
# ## Class Customer

# %% [markdown]
# Customers are passive with a chance of being at home (q). Response time follows an expovariate distribution. Unanswered deliveries return to the center.

# %%
class Customer:
    
    REGISTER = []

    def __init__(self, rec, location, q):
        self.rec = rec
        self.location = location
        self.q = q
        self.parcelsReceived = []
        self.i = len(Customer.REGISTER)
        Customer.REGISTER.append(self)
        
        
    def __str__(self):
        return f"Customer: {self.i:2d} {str(self.location):s}"
    
    # factory method ensures that there is only
    # one customer per location
    def getCustomer(rec, location, q=None):
        for c in Customer.REGISTER:
            if c.location == location:
                return c
        assert(q is not None)
        return Customer(rec, location, q)
    
    def responseTime(self):
        if random.random()<self.q:
            return math.inf # customer is not home
        else:
            return random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR)
            
    def acceptParcel(self, parcel):
        self.parcelsReceived.append(parcel.i)
        self.rec.recordParcelDelivery(parcel)

# %% [markdown]
# ## Class Driver

# %%
class Driver:
    
    def __init__(self, rec, DC, patience):
        self.rec = rec
        self.DC = DC
        self.patience = patience
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.recordDriverBeginsWork()
        
    def leaveForDelivery(self, tour, parcels):
        for p in parcels:
            yield self.rec.env.timeout(PREP_TIME_PER_PARCEL)
            p.outForDelivery()
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " \
                       f"of {len(parcels):d} parcels")
                
    def goHome(self):
        self.location = self.DC.W
        self.parcels = None
        self.returns = None
        self.tour = [ self.DC.W ]
        self.rec.recordDriverEndsWork()
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels = self.DC.sendForDelivery()
            yield from self.leaveForDelivery(tour, parcels)
            self.rec.recordTourLength(pathLength(tour))
            while len(self.parcels)>0:
                # drive to customer
                custLocation = self.parcels[0].dest
                cust = Customer.getCustomer(self.rec, custLocation)
                self.rec.trace("Driver drives to "+str(cust))
                yield from self.__drive(custLocation)
                self.rec.trace("Driver arrived at "+str(cust))
                wait_time = cust.responseTime()
                
                if wait_time<self.patience: 
                    # customer answered door

                    yield self.rec.env.timeout(wait_time)
                    self.rec.trace(str(cust)+" answers door")
                    while len(self.parcels)>0 and \
                            custLocation == self.parcels[0].dest:
                        handover_time = random.expovariate(1/AVERAGE_TIME_HANDOVER)
                        yield self.rec.env.timeout(handover_time)
                        cust.acceptParcel(self.parcels[0])
                        self.parcels = self.parcels[1:]
                    signoff_time = random.expovariate(1/AVERAGE_TIME_SIGNOFF)
                    yield self.rec.env.timeout(signoff_time)
                    self.rec.trace(str(cust)+" signed off")
                else:
                    # customer not at home or to slow
                    yield self.rec.env.timeout(self.patience)
                    self.rec.trace(str(cust)+" doesn't answer the door")
                    while len(self.parcels)>0 and  \
                            custLocation == self.parcels[0].dest:
                        self.returns.append(self.parcels[0])
                        self.parcels = self.parcels[1:]

            # return to delivery centre
            self.rec.trace("Driver returns to delivery centre")
            yield from self.__drive(self.DC.W)
            yield from self.DC.returnFromDelivery(self.returns)
            
            self.rec.recordParcelsLeftOver(len(self.DC.parcels)+
                                           len(self.DC.leftOver))

            self.goHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# ## Class Delivery Centre

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W, limit, heuristic):
        self.rec = rec
        self.M = M
        self.W = W
        self.D, self.P = FW(M)
        self.limit = limit
        self.heuristic = heuristic
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [W]       # tour planned for delivery
        
    # builds tour incrementally:
    # every single parcel is in the sequence of their
    # acceptance either incorporated into the tour or
    # assigned to left overs 
    def __accept(self, parcel):
        custLoc = parcel.dest
        if custLoc in self.dest:
            self.parcels.append(parcel)
        else:
            if self.heuristic:
                S = createLoopH(self.M, self.D, self.P, [self.W] + self.dest + [custLoc])
            else:
                S = createLoop(self.M, self.D, self.P, [self.W] + self.dest + [custLoc])
            if pathLength(S)<self.limit:
                self.parcels.append(parcel)
                self.dest.append(custLoc)
                self.tour = S
            else:
                self.leftOver.append(parcel)
            
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.rec.recordParcelArrival(parcel)
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = self.dest
        
        # pick parcels in sequence to be delivered
        for dest in tour:
            if dest in self.dest:
                for p in self.parcels:
                    if p.dest == dest:
                        parcels += [p]
         
        # rearrange the left overs
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)
        
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    grid=True, size=5,
                    text=f"Day {day(self.rec.env.now):2d}, {pathLength(tour):,d}m")

        return tour, parcels
                 
    def returnFromDelivery(self, parcels):
        for p in parcels:
            p.returnFromDelivery()
            yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
            self.__accept(p)
        yield self.rec.env.timeout(END_OF_DAY_TIME)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# The time to **process returned parcels** in the delivery centre is 30 sec per parcel.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average **customer time** to answer the door, accept a parcel, or signoff.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40
AVERAGE_TIME_HANDOVER = 10
AVERAGE_TIME_SIGNOFF = 10

# %% [markdown]
# The time for end of day closing procedure

# %%
END_OF_DAY_TIME = 600

# %% [markdown]
# ## Simulation Routine

# %%
def simulate_delivery(M, W, C, days, parcels_per_day=0.2, bike_range_limit=30000, customer_prob_not_home=0.1,
                      max_customer_wait_time=60, use_heuristic=False, log_output=False, plot_output=False,
                      show_ticks=False):

    P = generateParcels(days=days, p=parcels_per_day, customers=len(C))
        
    total_parcels = sum([len(d) for d in P])
    
    print(f"Simulating the delivery of {total_parcels:d} parcels "
          f"over {days:d} days to {len(C):d} customers") 
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, total_parcels, log=log_output, plot=plot_output)

    def generatorProcess(env):
                
        DC = DeliveryCentre(rec, M, W, bike_range_limit, use_heuristic)
        D = Driver(rec, DC, max_customer_wait_time)
        
        # Process the parcels day by day
        for CL in P: 
            
            if log_output:
                print()
            if show_ticks:
                print(".", end="")

            yield env.timeout(12 * 3600)  # Half-day
            for ci in CL:
                cust = Customer.getCustomer(rec, C[ci], customer_prob_not_home)
                p = Parcel(rec, cust)
                DC.acceptParcel(p)
            yield env.timeout(12 * 3600)  # Half-day

    env.process(generatorProcess(env))
    env.run()
    
    rec.finish()
    
    return rec

# %% [markdown]
# ## Model Verification

# %%
import pickle
with open('sampleData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
C
# Out:
# [(4546, 2567), (4421, 6466), (6818, 3195), (3285, 2769), (6698, 7149)]

# %%
W
# Out:
# (6458, 5010)

# %%
M
# Out:
# ([(2523, 5360),
#   (2596, 7555),
#   (3477, 2118),
#   (4150, 5463),
#   (4575, 3484),
#   (4582, 7057),
#   (6177, 3254),
#   (6458, 5010),
#   (8001, 7207),
#   (8005, 3086),
#   (4546, 2567),
#   (4421, 6466),
#   (6818, 3195),
#   (3285, 2769),
#   (6698, 7149)],
#  [((2523, 5360), (2596, 7555)),
#   ((2596, 7555), (4582, 7057)),
#   ((4150, 5463), (2523, 5360)),
#   ((4575, 3484), (3477, 2118)),
#   ((4575, 3484), (4150, 5463)),
#   ((4575, 3484), (6177, 3254)),
#   ((6177, 3254), (6458, 5010)),
#   ((6458, 5010), (4575, 3484)),
#   ((6458, 5010), (4582, 7057)),
#   ((8001, 7207), (6458, 5010)),
#   ((8005, 3086), (8001, 7207)),
#   ((6177, 3254), (4546, 2567)),
#   ((4546, 2567), (3477, 2118)),
#   ((4150, 5463), (4421, 6466)),
#   ((4421, 6466), (4582, 7057)),
#   ((8005, 3086), (6818, 3195)),
#   ((6818, 3195), (6177, 3254)),
#   ((3477, 2118), (3285, 2769)),
#   ((3285, 2769), (2523, 5360)),
#   ((4582, 7057), (6698, 7149)),
#   ((6698, 7149), (8001, 7207))])

# %%
plotMap(M, T=C, w=W, text='Sample Data', grid=True)

# %%
random.seed(0)
_ = simulate_delivery(M, W, C, days=4, parcels_per_day=0.4, bike_range_limit=30000, log_output=True, plot_output=True)
# Out:
# Simulating the delivery of 6 parcels over 4 days to 5 customers
#
# [ 0] 12:00:00.0 Parcel:  0 for customer 0 arr at delivery centre
# [ 0] 12:00:00.0 Parcel:  0 for customer 0 arrived in delivery centre
# [ 0] 12:00:00.0 Parcel:  1 for customer 1 arr at delivery centre
# [ 0] 12:00:00.0 Parcel:  1 for customer 1 arrived in delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:50.0 Parcel:  0 for customer 0 out for delivery
# [ 0] 18:01:40.0 Parcel:  1 for customer 1 out for delivery
# [ 0] 18:01:40.0 Driver leaves for delivery of 2 parcels
# [ 0] 18:01:40.0 Driver drives to Customer:  0 (6818, 3195)
# [ 0] 18:11:21.5 Driver arrived at Customer:  0 (6818, 3195)
# [ 0] 18:11:34.8 Customer:  0 (6818, 3195) answers door
# [ 0] 18:11:48.9 Parcel:  0 for customer 0 delivered to customer
# [ 0] 18:11:58.5 Customer:  0 (6818, 3195) signed off
# [ 0] 18:11:58.5 Driver drives to Customer:  1 (3285, 2769)
# [ 0] 18:28:59.2 Driver arrived at Customer:  1 (3285, 2769)
# [ 0] 18:29:59.2 Customer:  1 (3285, 2769) doesn't answer the door
# [ 0] 18:29:59.2 Driver returns to delivery centre
# [ 0] 18:49:24.7 Parcel:  1 for customer 1 return from delivery
# [ 0] 18:59:54.7 1 left over for next day
# [ 0] 18:59:54.7 Driver goes home
#
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:50.0 Parcel:  1 for customer 1 out for delivery
# [ 1] 18:00:50.0 Driver leaves for delivery of 1 parcels
# [ 1] 18:00:50.0 Driver drives to Customer:  1 (3285, 2769)
# [ 1] 18:20:15.4 Driver arrived at Customer:  1 (3285, 2769)
# [ 1] 18:21:15.4 Customer:  1 (3285, 2769) doesn't answer the door
# [ 1] 18:21:15.4 Driver returns to delivery centre
# [ 1] 18:40:40.9 Parcel:  1 for customer 1 return from delivery
# [ 1] 18:51:10.9 1 left over for next day
# [ 1] 18:51:10.9 Driver goes home
#
# [ 2] 12:00:00.0 Parcel:  2 for customer 0 arr at delivery centre
# [ 2] 12:00:00.0 Parcel:  2 for customer 0 arrived in delivery centre
# [ 2] 12:00:00.0 Parcel:  3 for customer 1 arr at delivery centre
# [ 2] 12:00:00.0 Parcel:  3 for customer 1 arrived in delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:50.0 Parcel:  1 for customer 1 out for delivery
# [ 2] 18:01:40.0 Parcel:  3 for customer 1 out for delivery
# [ 2] 18:02:30.0 Parcel:  2 for customer 0 out for delivery
# [ 2] 18:02:30.0 Driver leaves for delivery of 3 parcels
# [ 2] 18:02:30.0 Driver drives to Customer:  1 (3285, 2769)
# [ 2] 18:21:55.4 Driver arrived at Customer:  1 (3285, 2769)
# [ 2] 18:22:10.3 Customer:  1 (3285, 2769) answers door
# [ 2] 18:22:23.4 Parcel:  1 for customer 1 delivered to customer
# [ 2] 18:22:46.3 Parcel:  3 for customer 1 delivered to customer
# [ 2] 18:22:57.8 Customer:  1 (3285, 2769) signed off
# [ 2] 18:22:57.8 Driver drives to Customer:  0 (6818, 3195)
# [ 2] 18:39:58.5 Driver arrived at Customer:  0 (6818, 3195)
# [ 2] 18:40:02.8 Customer:  0 (6818, 3195) answers door
# [ 2] 18:40:08.5 Parcel:  2 for customer 0 delivered to customer
# [ 2] 18:40:17.9 Customer:  0 (6818, 3195) signed off
# [ 2] 18:40:17.9 Driver returns to delivery centre
# [ 2] 18:59:59.4 0 left over for next day
# [ 2] 18:59:59.4 Driver goes home
#
# [ 3] 12:00:00.0 Parcel:  4 for customer 2 arr at delivery centre
# [ 3] 12:00:00.0 Parcel:  4 for customer 2 arrived in delivery centre
# [ 3] 12:00:00.0 Parcel:  5 for customer 0 arr at delivery centre
# [ 3] 12:00:00.0 Parcel:  5 for customer 0 arrived in delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:50.0 Parcel:  4 for customer 2 out for delivery
# [ 3] 18:01:40.0 Parcel:  5 for customer 0 out for delivery
# [ 3] 18:01:40.0 Driver leaves for delivery of 2 parcels
# [ 3] 18:01:40.0 Driver drives to Customer:  2 (4421, 6466)
# [ 3] 18:15:13.6 Driver arrived at Customer:  2 (4421, 6466)
# [ 3] 18:16:13.6 Customer:  2 (4421, 6466) doesn't answer the door
# [ 3] 18:16:13.6 Driver drives to Customer:  0 (6818, 3195)
# [ 3] 18:37:32.1 Driver arrived at Customer:  0 (6818, 3195)
# [ 3] 18:38:32.1 Customer:  0 (6818, 3195) doesn't answer the door
# [ 3] 18:38:32.1 Driver returns to delivery centre
# [ 3] 18:48:13.6 Parcel:  4 for customer 2 return from delivery
# [ 3] 18:48:43.6 Parcel:  5 for customer 0 return from delivery
# [ 3] 18:59:13.6 2 left over for next day
# [ 3] 18:59:13.6 Driver goes home

# %% [markdown]
# ## Run Small Simulation

# %%
import pickle
with open('myData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
random.seed(0)
small_simulation = simulate_delivery(M, W, C, days=10, parcels_per_day=0.2, bike_range_limit=30000, 
                 use_heuristic=True, plot_output=True)
# Out:
# Simulating the delivery of 193 parcels over 10 days to 100 customers

# %% [markdown]
# ### Analysing Working Time

# %%
small_simulation.histWorkingTime()

# %%
small_simulation.plotWorkingTime()

# %% [markdown]
# ### Analyse Tour Length

# %%
small_simulation.histTourLength()

# %%
small_simulation.plotTourLength()

# %% [markdown]
# ### Analyse Number of Left-Over Parcels

# %%
small_simulation.histLeftOver()

# %%
small_simulation.plotLeftOver()

# %% [markdown]
# ### Analyse Delayed Parcel Delivery

# %%
small_simulation.tableParcelDelay()
# Out:
# Delivery Delay (193 parcels)
#    None:     50   25.9%
#  1 days:     55   28.5%
#  2 days:     43   22.3%
#  3 days:     16    8.3%
#  4 days:     14    7.3%
#  5 days:      9    4.7%
#  6 days:      0    0.0%
#  7 days:      2    1.0%
#  8 days:      2    1.0%
#  9 days:      2    1.0%

# %%
small_simulation.barplotParcelDelay()

# %%
small_simulation.plotParcelDelay()

# %% [markdown]
# ## Run Multiple Larger Simulation

# %%
def multiDeliverySimulation(seeds,        # seed values for simulation runs   
                    M, W, C,      # Geometry data
                    folder,    
                    days=50,     
                    parcels_per_day_and_customer=0.2,       
                    bike_range_limit=30000,  
                    customer_prob_not_home=0.1,       
                    max_customer_wait_time=60): 
    for seed in seeds:
        random.seed(seed)
        filename = f"simulation data days={days:d} parcels_per_day_and_customer={parcels_per_day_and_customer:2.2f} bike_range_limit={bike_range_limit:d} " + \
                   f"customer_prob_not_home={customer_prob_not_home:2.2f} max_customer_wait_time={max_customer_wait_time:d} seed={seed:d}"
        print(filename)
        rec = simulate_delivery(M, W, C, 
                         days=days, parcels_per_day=parcels_per_day_and_customer, bike_range_limit=bike_range_limit, customer_prob_not_home=customer_prob_not_home, max_customer_wait_time=max_customer_wait_time, 
                         use_heuristic=True, show_ticks=True)
        with open(f'{folder}/'+filename, 'wb') as f:
            pickle.dump(rec, f)
        print()

# %%
def loadDeliverySimulations(seeds,        # seed values for simulation runs   
                    folder,
                    days=50,      
                    parcels_per_day_and_customer=0.2,         
                    bike_range_limit=30000,  
                    customer_prob_not_home=0.1,        
                    max_customer_wait_time=60): 
    recs = []
    for seed in seeds:
        random.seed(seed)
        filename = f"simulation data days={days:d} parcels_per_day_and_customer={parcels_per_day_and_customer:2.2f} bike_range_limit={bike_range_limit:d} " + \
                   f"customer_prob_not_home={customer_prob_not_home:2.2f} max_customer_wait_time={max_customer_wait_time:d} seed={seed:d}"
        print(filename)
        with open(f'{folder}/'+filename, 'rb') as f:
            rec = pickle.load(f)
            recs.append(rec)
    return recs

# %% [markdown]
# ### Run Simulations

# %%
import pickle
with open('myData.pickled', 'rb') as f:
    M, W, C = pickle.load(f)

# %%
bike_ranges=[30000,35000,40000,45000]

# %%
import time

# %%
def perform_analysis(data_list,names_list):
    """
    Perform analysis on a list of data.

    Parameters:
        data_list (list): A list containing data objects.
        names_list (list):A list containing data objects names.

    Returns:
        None: This function performs the analysis and generates plots but does not return anything.
    """
    for i, data in enumerate(data_list):
        data_name = names_list[i]
        print()
        print(f"Data {i}: {data_name}",flush=True)

        print("Histogram of Working Time:",flush=True)
        data.histWorkingTime()
        plt.show()

        print("Plot of Working Time:",flush=True)
        data.plotWorkingTime()
        plt.show()

        print("Histogram of Tour Length:",flush=True)
        data.histTourLength()
        plt.show()

        print("Plot of Tour Length:",flush=True)
        data.plotTourLength()
        plt.show()

        print("Histogram of Left Over:",flush=True)
        data.histLeftOver()
        plt.show()

        print("Plot of Left Over:",flush=True)
        data.plotLeftOver()
        plt.show()

        print("Parcel Delay Table and Plot:",flush=True)
        data.tableParcelDelay()
        plt.show()
        data.plotParcelDelay()
        plt.show()

        print("Parcel Delay Bar Plot:",flush=True)
        data.barplotParcelDelay()
        plt.show()
        
        print()
        time.sleep(2)

# %% [markdown]
# # p=0.21

# %%
for bike_range in bike_ranges:
    bike_r = bike_range//1000
    multiDeliverySimulation(range(20,30), M, W, C,f'sim0.21_{bike_r}km',parcels_per_day_and_customer=0.21,bike_range_limit=bike_range, days=50)
# Out:
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1056 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1053 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1065 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1064 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1009 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1066 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1084 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1038 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1056 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1053 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1065 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1064 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1009 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1066 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1084 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1038 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1056 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1053 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1065 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1064 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1009 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1066 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1084 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1038 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1056 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1053 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1065 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1064 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1009 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1066 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1084 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 979 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1038 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1052 parcels over 50 days to 100 customers
# ..................................................

# %% [markdown]
# ### Simulations for p=0.21 and 30km,35km,40km and 45km bike ranges

# %%
sims21_30km = loadDeliverySimulations(range(20,30),'sim0.21_30km',parcels_per_day_and_customer=0.21,bike_range_limit=30000, days=50)
sim21_30km = combineRecorders(sims21_30km)
sims21_35km = loadDeliverySimulations(range(20,30),'sim0.21_35km',parcels_per_day_and_customer=0.21,bike_range_limit=35000, days=50)
sim21_35km = combineRecorders(sims21_35km)
sims21_40km = loadDeliverySimulations(range(20,30),'sim0.21_40km',parcels_per_day_and_customer=0.21,bike_range_limit=40000, days=50)
sim21_40km = combineRecorders(sims21_40km)
sims21_45km = loadDeliverySimulations(range(20,30),'sim0.21_45km',parcels_per_day_and_customer=0.21,bike_range_limit=45000, days=50)
sim21_45km = combineRecorders(sims21_45km)
# Out:
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.21 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29

# %%
data_list = [sim21_30km, sim21_35km, sim21_40km, sim21_45km]
names_list =['sim21_30km', 'sim21_35km', 'sim21_40km', 'sim21_45km']
perform_analysis(data_list,names_list)
# Out:
# Data 0: sim21_30km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (10466 parcels)
#    None:   2321   22.2%
#  1 days:   2212   21.1%
#  2 days:   2373   22.7%
#  3 days:   1464   14.0%
#  4 days:    602    5.8%
#  5 days:    548    5.2%
#  6 days:    353    3.4%
#  7 days:    193    1.8%
#  8 days:    138    1.3%
#  9 days:     99    0.9%
# 10 days:     48    0.5%
# 11 days:     44    0.4%
# 12 days:     21    0.2%
# 13 days:     20    0.2%
# 14 days:      7    0.1%
# 15 days:      5    0.0%
# 16 days:      3    0.0%
# 17 days:      6    0.1%
# 18 days:      4    0.0%
# 19 days:      0    0.0%
# 20 days:      1    0.0%
# 21 days:      0    0.0%
# 22 days:      1    0.0%
# 23 days:      1    0.0%
# 24 days:      1    0.0%
# 25 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 1: sim21_35km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (10466 parcels)
#    None:   2859   27.3%
#  1 days:   3630   34.7%
#  2 days:   1887   18.0%
#  3 days:    943    9.0%
#  4 days:    521    5.0%
#  5 days:    292    2.8%
#  6 days:    156    1.5%
#  7 days:     79    0.8%
#  8 days:     45    0.4%
#  9 days:     25    0.2%
# 10 days:     16    0.2%
# 11 days:      2    0.0%
# 12 days:      5    0.0%
# 13 days:      1    0.0%
# 14 days:      1    0.0%
# 15 days:      3    0.0%
# 16 days:      0    0.0%
# 17 days:      0    0.0%
# 18 days:      0    0.0%
# 19 days:      0    0.0%
# 20 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 2: sim21_40km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (10466 parcels)
#    None:   3858   36.9%
#  1 days:   4317   41.2%
#  2 days:   1293   12.4%
#  3 days:    625    6.0%
#  4 days:    212    2.0%
#  5 days:     86    0.8%
#  6 days:     35    0.3%
#  7 days:     21    0.2%
#  8 days:     10    0.1%
#  9 days:      7    0.1%
# 10 days:      1    0.0%
# 11 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 3: sim21_45km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (10466 parcels)
#    None:   5559   53.1%
#  1 days:   3283   31.4%
#  2 days:   1081   10.3%
#  3 days:    368    3.5%
#  4 days:    115    1.1%
#  5 days:     39    0.4%
#  6 days:     14    0.1%
#  7 days:      6    0.1%
#  8 days:      1    0.0%
# Parcel Delay Bar Plot:

# %% [markdown]
# # p=0.26

# %%
for bike_range in bike_ranges:
    bike_r=bike_range//1000
    multiDeliverySimulation(range(20,30), M, W, C,f'sim0.26_{bike_r}km',parcels_per_day_and_customer=0.26,bike_range_limit=bike_range, days=50)
# Out:
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1340 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1287 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1300 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1317 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1260 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1269 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1324 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1226 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1292 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1314 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1340 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1287 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1300 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1317 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1260 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1269 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1324 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1226 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1292 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1314 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1340 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1287 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1300 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1317 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1260 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1269 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1324 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1226 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1292 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1314 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1340 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1287 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1300 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1317 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1260 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1269 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1324 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1226 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1292 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1314 parcels over 50 days to 100 customers
# ..................................................

# %% [markdown]
# ### Simulations for p=0.26 and 30km,35km,40km and 45km bike ranges

# %%
sims26_30km = loadDeliverySimulations(range(20,30),'sim0.26_30km',parcels_per_day_and_customer=0.26,bike_range_limit=30000, days=50)
sim26_30km = combineRecorders(sims26_30km)
sims26_35km = loadDeliverySimulations(range(20,30),'sim0.26_35km',parcels_per_day_and_customer=0.26,bike_range_limit=35000, days=50)
sim26_35km = combineRecorders(sims26_35km)
sims26_40km = loadDeliverySimulations(range(20,30),'sim0.26_40km',parcels_per_day_and_customer=0.26,bike_range_limit=40000, days=50)
sim26_40km = combineRecorders(sims26_40km)
sims26_45km = loadDeliverySimulations(range(20,30),'sim0.26_45km',parcels_per_day_and_customer=0.26,bike_range_limit=45000, days=50)
sim26_45km = combineRecorders(sims26_45km)
# Out:
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.26 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29

# %%
data_list2 = [sim26_30km, sim26_35km, sim26_40km, sim26_45km]
names_list2 =['sim26_30km', 'sim26_35km', 'sim26_40km', 'sim26_45km']
perform_analysis(data_list2,names_list2)
# Out:
# Data 0: sim26_30km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (12929 parcels)
#    None:   2816   21.8%
#  1 days:   2681   20.7%
#  2 days:   2668   20.6%
#  3 days:   1928   14.9%
#  4 days:    793    6.1%
#  5 days:    709    5.5%
#  6 days:    514    4.0%
#  7 days:    279    2.2%
#  8 days:    183    1.4%
#  9 days:    121    0.9%
# 10 days:     83    0.6%
# 11 days:     50    0.4%
# 12 days:     39    0.3%
# 13 days:     20    0.2%
# 14 days:     12    0.1%
# 15 days:     10    0.1%
# 16 days:     11    0.1%
# 17 days:      6    0.0%
# 18 days:      2    0.0%
# 19 days:      0    0.0%
# 20 days:      2    0.0%
# 21 days:      1    0.0%
# 22 days:      0    0.0%
# 23 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 1: sim26_35km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (12929 parcels)
#    None:   3248   25.1%
#  1 days:   3811   29.5%
#  2 days:   2932   22.7%
#  3 days:   1153    8.9%
#  4 days:    781    6.0%
#  5 days:    451    3.5%
#  6 days:    235    1.8%
#  7 days:    146    1.1%
#  8 days:     77    0.6%
#  9 days:     43    0.3%
# 10 days:     25    0.2%
# 11 days:     13    0.1%
# 12 days:      7    0.1%
# 13 days:      2    0.0%
# 14 days:      1    0.0%
# 15 days:      0    0.0%
# 16 days:      3    0.0%
# 17 days:      0    0.0%
# 18 days:      0    0.0%
# 19 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 2: sim26_40km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (12929 parcels)
#    None:   4081   31.6%
#  1 days:   5257   40.7%
#  2 days:   1742   13.5%
#  3 days:   1004    7.8%
#  4 days:    415    3.2%
#  5 days:    240    1.9%
#  6 days:    103    0.8%
#  7 days:     38    0.3%
#  8 days:     27    0.2%
#  9 days:     13    0.1%
# 10 days:      5    0.0%
# 11 days:      2    0.0%
# 12 days:      1    0.0%
# 13 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 3: sim26_45km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (12929 parcels)
#    None:   5694   44.0%
#  1 days:   4806   37.2%
#  2 days:   1502   11.6%
#  3 days:    612    4.7%
#  4 days:    192    1.5%
#  5 days:     80    0.6%
#  6 days:     27    0.2%
#  7 days:     14    0.1%
#  8 days:      2    0.0%
# Parcel Delay Bar Plot:

# %% [markdown]
# # p=0.28

# %%
for bike_range in bike_ranges:
    bike_r = bike_range//1000
    multiDeliverySimulation(range(20,30), M, W, C,f'sim0.28_{bike_r}km',parcels_per_day_and_customer=0.28,bike_range_limit=bike_range, days=50)
# Out:
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1419 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1387 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1411 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1430 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1356 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1388 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1416 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1336 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1397 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1389 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1419 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1387 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1411 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1430 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1356 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1388 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1416 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1336 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1397 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1389 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1419 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1387 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1411 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1430 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1356 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1388 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1416 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1336 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1397 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1389 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# Simulating the delivery of 1419 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# Simulating the delivery of 1387 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# Simulating the delivery of 1411 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# Simulating the delivery of 1430 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# Simulating the delivery of 1356 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# Simulating the delivery of 1388 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# Simulating the delivery of 1416 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# Simulating the delivery of 1336 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# Simulating the delivery of 1397 parcels over 50 days to 100 customers
# ..................................................
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# Simulating the delivery of 1389 parcels over 50 days to 100 customers
# ..................................................

# %% [markdown]
# ### Simulations for p=0.28 and 30km,35km,40km and 45km bike ranges

# %%
sims28_30km = loadDeliverySimulations(range(20,30),'sim0.28_30km',parcels_per_day_and_customer=0.28,bike_range_limit=30000, days=50)
sim28_30km = combineRecorders(sims28_30km)
sims28_35km = loadDeliverySimulations(range(20,30),'sim0.28_35km',parcels_per_day_and_customer=0.28,bike_range_limit=35000, days=50)
sim28_35km = combineRecorders(sims28_35km)
sims28_40km = loadDeliverySimulations(range(20,30),'sim0.28_40km',parcels_per_day_and_customer=0.28,bike_range_limit=40000, days=50)
sim28_40km = combineRecorders(sims28_40km)
sims28_45km = loadDeliverySimulations(range(20,30),'sim0.28_45km',parcels_per_day_and_customer=0.28,bike_range_limit=45000, days=50)
sim28_45km = combineRecorders(sims28_45km)
# Out:
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=30000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=35000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=40000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=20
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=21
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=22
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=23
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=24
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=25
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=26
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=27
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=28
# simulation data days=50 parcels_per_day_and_customer=0.28 bike_range_limit=45000 customer_prob_not_home=0.10 max_customer_wait_time=60 seed=29

# %%
data_list3 = [sim28_30km, sim28_35km, sim28_40km, sim28_45km]
names_list3 =['sim28_30km', 'sim28_35km', 'sim28_40km', 'sim28_45km']
perform_analysis(data_list3,names_list3)
# Out:
# Data 0: sim28_30km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (13929 parcels)
#    None:   2945   21.1%
#  1 days:   2744   19.7%
#  2 days:   2610   18.7%
#  3 days:   2343   16.8%
#  4 days:    922    6.6%
#  5 days:    712    5.1%
#  6 days:    564    4.0%
#  7 days:    372    2.7%
#  8 days:    224    1.6%
#  9 days:    160    1.1%
# 10 days:    114    0.8%
# 11 days:     76    0.5%
# 12 days:     39    0.3%
# 13 days:     36    0.3%
# 14 days:     23    0.2%
# 15 days:     10    0.1%
# 16 days:     14    0.1%
# 17 days:      9    0.1%
# 18 days:      2    0.0%
# 19 days:      6    0.0%
# 20 days:      0    0.0%
# 21 days:      1    0.0%
# 22 days:      0    0.0%
# 23 days:      0    0.0%
# 24 days:      2    0.0%
# 25 days:      0    0.0%
# 26 days:      0    0.0%
# 27 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 1: sim28_35km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (13929 parcels)
#    None:   3558   25.5%
#  1 days:   3953   28.4%
#  2 days:   3392   24.4%
#  3 days:   1131    8.1%
#  4 days:    833    6.0%
#  5 days:    489    3.5%
#  6 days:    248    1.8%
#  7 days:    149    1.1%
#  8 days:     57    0.4%
#  9 days:     46    0.3%
# 10 days:     25    0.2%
# 11 days:     24    0.2%
# 12 days:      8    0.1%
# 13 days:      9    0.1%
# 14 days:      2    0.0%
# 15 days:      3    0.0%
# 16 days:      1    0.0%
# 17 days:      1    0.0%
# Parcel Delay Bar Plot:
# Data 2: sim28_40km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (13929 parcels)
#    None:   4413   31.7%
#  1 days:   5525   39.7%
#  2 days:   1833   13.2%
#  3 days:   1136    8.2%
#  4 days:    498    3.6%
#  5 days:    278    2.0%
#  6 days:    119    0.9%
#  7 days:     66    0.5%
#  8 days:     32    0.2%
#  9 days:     17    0.1%
# 10 days:      7    0.1%
# 11 days:      3    0.0%
# 12 days:      0    0.0%
# 13 days:      2    0.0%
# Parcel Delay Bar Plot:
# Data 3: sim28_45km
# Histogram of Working Time:
# Plot of Working Time:
# Histogram of Tour Length:
# Plot of Tour Length:
# Histogram of Left Over:
# Plot of Left Over:
# Parcel Delay Table and Plot:
# Delivery Delay (13929 parcels)
#    None:   5631   40.4%
#  1 days:   5382   38.6%
#  2 days:   1828   13.1%
#  3 days:    686    4.9%
#  4 days:    252    1.8%
#  5 days:     93    0.7%
#  6 days:     39    0.3%
#  7 days:     12    0.1%
#  8 days:      4    0.0%
#  9 days:      1    0.0%
# 10 days:      1    0.0%
# Parcel Delay Bar Plot:
